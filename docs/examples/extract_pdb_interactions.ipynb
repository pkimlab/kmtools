# %% [markdown]
# # Extract PDB interactions

# %%
from kmtools import structure_tools

# %%
s = structure_tools.fetch_structure('4dkl', pdb_type='cif')

# %%
structure_tools.process_structure(s)

# %%
df = structure_tools.get_interactions(s)

# %%
df
# Out:
#      structure_id  model_id_1  model_id_2 chain_id_1 chain_id_2  residue_id_1  \
# 0            4dkl           0           0          A          A             0
# 1            4dkl           0           0          A          A             0
# 2            4dkl           0           0          A          A             0
# 3            4dkl           0           0          A          A             0
# 4            4dkl           0           0          A          A             0
# 5            4dkl           0           0          A          A             1
# 6            4dkl           0           0          A          A             1
# 7            4dkl           0           0          A          A             1
# 8            4dkl           0           0          A          A             1
# 9            4dkl           0           0          A          A             1
# 10           4dkl           0           0          A          A             1
# ...
